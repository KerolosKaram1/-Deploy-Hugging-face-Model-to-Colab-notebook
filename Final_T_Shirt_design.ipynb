# %%
import requests
import io
from PIL import Image
from IPython.display import display
import random
import string

API_URL = "https://api-inference.huggingface.co/models/artificialguybr/TshirtDesignRedmond-V2"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.content

# Take user input for the prompt
user_input = input("Enter a prompt (press Enter for default): ")

# Use a default prompt if the user didn't provide any input
default_prompt = "TshirtDesignAF, T Shirt Design"
prompt = user_input.strip() if user_input else default_prompt
#random
random_suffix = ''.join(random.choice(string.ascii_letters) for _ in range(3))
modified_prompt = f"{prompt} {random_suffix}"


image_bytes = query({
    "inputs": modified_prompt,
})

image = Image.open(io.BytesIO(image_bytes))

new_size = (500, 500)
image = image.resize(new_size)

display(image)
#TshirtDesignAF, T Shirt Design
# Out:
# Enter a prompt (press Enter for default):
# <PIL.Image.Image image mode=RGB size=500x500>
